# %% [markdown]
# EDA
# Exploratory Data Analysis

# %%
in simple words data koo explore karna k data k andr kia hai ( means that data koo analyze
karna aur summarize karna)
# Out:
#   Cell In[11], line 1
#     in simple words data koo explore karna k data k andr kia hai ( means that data koo analyze
#     ^
# SyntaxError: invalid syntax

# %%
 import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# pehlat data analyze kartey hai

# %%
# import data set 
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.shape
# Out:
# (891, 15)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# aur ab data summarise kartey hai ,esko summary ststistics bhee kehtey hai

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# find null values 
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
finding unique values

# %%
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# visualize the nan value in heatmap

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
df.drop(columns="deck", inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 14)

# %%
# visualize and explore  
sns.countplot(data=df, x="survived")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.barplot(data=df, x="survived", y="age", hue="who")
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.barplot(data=df, x="survived", y="fare", hue="who")
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.countplot(x="pclass", data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
# how to distribute data

# %%
sns.histplot(data=df, x="age")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
bins ka mtlb hai group of people starting from zero point to the maximum point 
mtlb pehlay aik chiz koo aline karna aur phir unn k groups banana,es tara bins bntey 
hai hai aur data koo dstribute kartey hai

# %%
sns.histplot(data=df, x="age", bins=8)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
alpha es liye yahan py laga hai for opecity mtlb colour koo dark ya light karna

# %%
df["age"].hist(bins=30, color="darkred", alpha=0.7)
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x="age")
# Out:
# <Axes: xlabel='age'>

# %%
uper x py age liya hai nichey y py liya hai

# %%
sns.boxplot(data=df, y="age")
# Out:
# <Axes: ylabel='age'>

# %%
Two numeric variable plot

# %%
sns.boxplot(data=df, x="age", y="fare")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.boxplot(data=df, y="age", x="survived", hue="who")
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
when you create box plot remember that we take always one side categorical value and one side  
we take numerical value, cetegorical means jis kee unique values kam hoo

# %%
#scaterrplot

# %%
 sns.scatterplot(x="age", y="fare",data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
 sns.scatterplot(x="age", y="fare",data=df) 
 plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %%
agr data koo limit deni hoo too ye uper wala command use karain ,k plot yahan sy ly kar yahan tak 
hoo means es value sy ly kar es value tak hoo

# %%
sns.pairplot(df,hue="survived")

# %%
sns.pairplot(df)

# %%
har aik ka dusrey  parameter k sath relation daikhney k liye pair plot bnaya jata hai

# %%
# staked bar chart/plot mtlb tehoon wala

# %%
df.groupby(["pclass", "sex"])["survived"].mean().unstack().plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='pclass'>

# %%
df.groupby(["pclass", "who"])["survived"].mean().unstack().plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='pclass'>

# %%
df.groupby(["pclass", "who"])["fare"].mean().unstack().plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='pclass'>

# %%
# swarm 
sns.swarmplot(data=df,x="age", y="fare")
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.swarmplot(data=df,x="survived", y="fare")
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 58.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 28.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='survived', ylabel='fare'>
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 68.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.swarmplot(data=df,x="survived", y="age")
# Out:
# <Axes: xlabel='survived', ylabel='age'>
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df,x="survived", y="age", hue="who")
# Out:
# <Axes: xlabel='survived', ylabel='age'>
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
point plot

# %%
sns.catplot(x="pclass", y="fare", hue="embarked", kind="point", data=df)

# %%
# relation of two numeric variable which is called LM plot

# %%
sns.lmplot(data=df, x="fare",y="age")

# %%
sns.lmplot(data=df, x="age",y="fare")

# %%
sns.lmplot(data=df, x="age", y= "fare",hue="pclass") 
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %%
# how to add a column and make a age group (grouping of columns )

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df["age_groups"] = pd.cut(df["age"], [0,10,18,30,50,80], 
  labels=["kids", "child", "youth", "middle aged", "old"])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone   age_groups
# 0    man        True  Southampton    no  False        youth
# 1  woman       False    Cherbourg   yes  False  middle aged
# 2  woman       False  Southampton   yes   True        youth
# 3  woman       False  Southampton   yes  False  middle aged
# 4    man        True  Southampton    no   True  middle aged

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'age_groups'],
#       dtype='object')

# %%
df.groupby("age_groups")["survived"].mean().plot(kind="bar")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11680\4035321093.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("age_groups")["survived"].mean().plot(kind="bar")
# <Axes: xlabel='age_groups'>

# %%
sns.pairplot(df,hue= "survived", vars=["age", "fare", "pclass"])
