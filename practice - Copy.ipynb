# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\hp\Desktop\PRACTICE\CATTLE.xlsx")

# %%
df.head()
# Out:
#    ID TagNumber      Breed  Gender  BirthDate  Weight            Color  \
# 0   1      T001   Holstein  Female 2022-01-12     500  Black and white
# 1   2      T002      Angus    Male 2021-05-20     600            Black
# 2   3      T003   Hereford  Female 2022-03-15     550    Red and white
# 3   4      T004  Simmental    Male 2021-11-08     650              Red
# 4   5      T005  Charolais  Female 2022-02-28     580            White
#
#    IsPregnant  MotherID  FatherID
# 0           1       NaN       NaN
# 1           0       NaN       NaN
# 2           1       1.0       2.0
# 3           0       NaN       NaN
# 4           1       3.0       4.0

# %%
df.tail
# Out:
# <bound method NDFrame.tail of     ID TagNumber        Breed  Gender  BirthDate  Weight            Color  \
# 0    1      T001     Holstein  Female 2022-01-12     500  Black and white
# 1    2      T002        Angus    Male 2021-05-20     600            Black
# 2    3      T003     Hereford  Female 2022-03-15     550    Red and white
# 3    4      T004    Simmental    Male 2021-11-08     650              Red
# 4    5      T005    Charolais  Female 2022-02-28     580            White
# 5    6      T006     Limousin    Male 2021-08-18     620           Yellow
# 6    7      T007     Gelbvieh  Female 2022-06-01     570            Brown
# 7    8      T008    Shorthorn    Male 2021-12-25     630    Red and white
# 8    9      T009      Brahman  Female 2022-04-10     590             Gray
# 9   10      T010  Maine-Anjou    Male 2021-09-05     640    Red and white
# 10  11      T011     Chianina  Female 2022-07-22     560            White
# ...

# %%
df.shape
# Out:
# (48, 10)

# %%
df.head(10)
# Out:
#    ID TagNumber        Breed  Gender  BirthDate  Weight            Color  \
# 0   1      T001     Holstein  Female 2022-01-12     500  Black and white
# 1   2      T002        Angus    Male 2021-05-20     600            Black
# 2   3      T003     Hereford  Female 2022-03-15     550    Red and white
# 3   4      T004    Simmental    Male 2021-11-08     650              Red
# 4   5      T005    Charolais  Female 2022-02-28     580            White
# 5   6      T006     Limousin    Male 2021-08-18     620           Yellow
# 6   7      T007     Gelbvieh  Female 2022-06-01     570            Brown
# 7   8      T008    Shorthorn    Male 2021-12-25     630    Red and white
# 8   9      T009      Brahman  Female 2022-04-10     590             Gray
# 9  10      T010  Maine-Anjou    Male 2021-09-05     640    Red and white
#
#    IsPregnant  MotherID  FatherID
# 0           1       NaN       NaN
# 1           0       NaN       NaN
# 2           1       1.0       2.0
# ...

# %%
df.tail(6)
# Out:
#     ID TagNumber        Breed  Gender  BirthDate  Weight          Color  \
# 42  43      T043    Simmental  Female 2022-05-20     570            Red
# 43  44      T044    Charolais    Male 2021-11-18     630          White
# 44  45      T045     Limousin  Female 2022-03-15     590         Yellow
# 45  46      T046     Gelbvieh    Male 2021-09-02     640          Brown
# 46  47      T047      Brahman  Female 2022-06-25     560           Gray
# 47  48      T048  Maine-Anjou    Male 2021-12-22     620  Red and white
#
#     IsPregnant  MotherID  FatherID
# 42           1      41.0      42.0
# 43           0       NaN       NaN
# 44           1      43.0      44.0
# 45           0       NaN       NaN
# 46           1      45.0      46.0
# 47           0       NaN       NaN

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\hp\Desktop\PRACTICE\CATTLE.xlsx")

# %%
df.head()
# Out:
#    ID TagNumber      Breed  Gender  BirthDate  Weight            Color  \
# 0   1      T001   Holstein  Female 2022-01-12     500  Black and white
# 1   2      T002      Angus    Male 2021-05-20     600            Black
# 2   3      T003   Hereford  Female 2022-03-15     550    Red and white
# 3   4      T004  Simmental    Male 2021-11-08     650              Red
# 4   5      T005  Charolais  Female 2022-02-28     580            White
#
#    IsPregnant  MotherID  FatherID
# 0           1       NaN       NaN
# 1           0       NaN       NaN
# 2           1       1.0       2.0
# 3           0       NaN       NaN
# 4           1       3.0       4.0

# %% [markdown]
# view data frames in python using pandas

# %%
df.head
# Out:
# <bound method NDFrame.head of     ID TagNumber        Breed  Gender  BirthDate  Weight            Color  \
# 0    1      T001     Holstein  Female 2022-01-12     500  Black and white
# 1    2      T002        Angus    Male 2021-05-20     600            Black
# 2    3      T003     Hereford  Female 2022-03-15     550    Red and white
# 3    4      T004    Simmental    Male 2021-11-08     650              Red
# 4    5      T005    Charolais  Female 2022-02-28     580            White
# 5    6      T006     Limousin    Male 2021-08-18     620           Yellow
# 6    7      T007     Gelbvieh  Female 2022-06-01     570            Brown
# 7    8      T008    Shorthorn    Male 2021-12-25     630    Red and white
# 8    9      T009      Brahman  Female 2022-04-10     590             Gray
# 9   10      T010  Maine-Anjou    Male 2021-09-05     640    Red and white
# 10  11      T011     Chianina  Female 2022-07-22     560            White
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of     ID TagNumber        Breed  Gender  BirthDate  Weight            Color  \
# 0    1      T001     Holstein  Female 2022-01-12     500  Black and white
# 1    2      T002        Angus    Male 2021-05-20     600            Black
# 2    3      T003     Hereford  Female 2022-03-15     550    Red and white
# 3    4      T004    Simmental    Male 2021-11-08     650              Red
# 4    5      T005    Charolais  Female 2022-02-28     580            White
# 5    6      T006     Limousin    Male 2021-08-18     620           Yellow
# 6    7      T007     Gelbvieh  Female 2022-06-01     570            Brown
# 7    8      T008    Shorthorn    Male 2021-12-25     630    Red and white
# 8    9      T009      Brahman  Female 2022-04-10     590             Gray
# 9   10      T010  Maine-Anjou    Male 2021-09-05     640    Red and white
# 10  11      T011     Chianina  Female 2022-07-22     560            White
# ...

# %%
df.shape
# Out:
# (48, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of     ID TagNumber        Breed  Gender  BirthDate  Weight            Color  \
# 0    1      T001     Holstein  Female 2022-01-12     500  Black and white
# 1    2      T002        Angus    Male 2021-05-20     600            Black
# 2    3      T003     Hereford  Female 2022-03-15     550    Red and white
# 3    4      T004    Simmental    Male 2021-11-08     650              Red
# 4    5      T005    Charolais  Female 2022-02-28     580            White
# 5    6      T006     Limousin    Male 2021-08-18     620           Yellow
# 6    7      T007     Gelbvieh  Female 2022-06-01     570            Brown
# 7    8      T008    Shorthorn    Male 2021-12-25     630    Red and white
# 8    9      T009      Brahman  Female 2022-04-10     590             Gray
# 9   10      T010  Maine-Anjou    Male 2021-09-05     640    Red and white
# 10  11      T011     Chianina  Female 2022-07-22     560            White
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=48, step=1)

# %%
df.coloums()

# %%
df.describe()
# Out:
#           ID            BirthDate     Weight  IsPregnant  MotherID  FatherID
# count  48.00                   48   48.00000   48.000000  23.00000  23.00000
# mean   24.50  2022-01-25 04:30:00  596.87500    0.500000  23.00000  24.00000
# min     1.00  2021-05-20 00:00:00  500.00000    0.000000   1.00000   2.00000
# 25%    12.75  2021-10-26 12:00:00  570.00000    0.000000  12.00000  13.00000
# 50%    24.50  2022-01-03 00:00:00  595.00000    0.500000  23.00000  24.00000
# 75%    36.25  2022-05-05 06:00:00  630.00000    1.000000  34.00000  35.00000
# max    48.00  2022-07-29 00:00:00  650.00000    1.000000  45.00000  46.00000
# std    14.00                  NaN   34.03104    0.505291  13.56466  13.56466

# %%
df.T
# Out:
#                              0                    1                    2   \
# ID                            1                    2                    3
# TagNumber                  T001                 T002                 T003
# Breed                  Holstein                Angus             Hereford
# Gender                   Female                 Male               Female
# BirthDate   2022-01-12 00:00:00  2021-05-20 00:00:00  2022-03-15 00:00:00
# Weight                      500                  600                  550
# Color           Black and white                Black        Red and white
# IsPregnant                    1                    0                    1
# MotherID                    NaN                  NaN                  1.0
# FatherID                    NaN                  NaN                  2.0
#
#                              3                    4                    5   \
# ID                            4                    5                    6
# ...

# %%
df.sort_index()
# Out:
#     ID TagNumber        Breed  Gender  BirthDate  Weight            Color  \
# 0    1      T001     Holstein  Female 2022-01-12     500  Black and white
# 1    2      T002        Angus    Male 2021-05-20     600            Black
# 2    3      T003     Hereford  Female 2022-03-15     550    Red and white
# 3    4      T004    Simmental    Male 2021-11-08     650              Red
# 4    5      T005    Charolais  Female 2022-02-28     580            White
# 5    6      T006     Limousin    Male 2021-08-18     620           Yellow
# 6    7      T007     Gelbvieh  Female 2022-06-01     570            Brown
# 7    8      T008    Shorthorn    Male 2021-12-25     630    Red and white
# 8    9      T009      Brahman  Female 2022-04-10     590             Gray
# 9   10      T010  Maine-Anjou    Male 2021-09-05     640    Red and white
# 10  11      T011     Chianina  Female 2022-07-22     560            White
# 11  12      T012       Salers    Male 2021-10-15     610              Tan
# ...

# %%
df.sort_index(ascending=False)
# Out:
#     ID TagNumber        Breed  Gender  BirthDate  Weight            Color  \
# 47  48      T048  Maine-Anjou    Male 2021-12-22     620    Red and white
# 46  47      T047      Brahman  Female 2022-06-25     560             Gray
# 45  46      T046     Gelbvieh    Male 2021-09-02     640            Brown
# 44  45      T045     Limousin  Female 2022-03-15     590           Yellow
# 43  44      T044    Charolais    Male 2021-11-18     630            White
# 42  43      T043    Simmental  Female 2022-05-20     570              Red
# 41  42      T042        Angus    Male 2021-11-10     640            Black
# 40  41      T041     Hereford  Female 2022-07-08     580    Red and white
# 39  40      T040    Shorthorn    Male 2021-09-26     620    Red and white
# 38  39      T039      Milking  Female 2022-05-01     560            White
# 37  38      T038       Jersey    Male 2021-12-15     610             Fawn
# 36  37      T037     Guernsey  Female 2022-06-20     550             Fawn
# ...

# %%
df.sort_values

# %%
pd.show_v
