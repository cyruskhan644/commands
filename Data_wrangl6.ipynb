# %% [markdown]
# # Data wrangling

# %%
Data wrangling the process of cleaning , transforming , and organising data so that it can be used 
for analysis and visualization , it is an important step in the data analysis process because 
raw data is often incomplete , inconsistent, and in an unstructured format, which can make it difficult
 to work with.
  data wrangling helps to make the data more consistent , accurate, and useful 
 for analysis and decision making .

# %%
# libraries 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.load_dataset("titanic")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
find the missing values

# %%
df.isnull().sum() / len(df) *100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.drop(columns="deck")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.drop(columns="deck", inplace=True)

# %%
df = df.drop("age", axis=1)

# %%
df["embark_town"] = df.embark_town.fillna(value =df["embark_town"].mode()[0])

# %%
df.isnull().sum() / len(df) *100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.000000
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
ab hamarey pas koi percentage nai rahee null values aur remove kar dee missinig values aur null values

# %% [markdown]
# # outlier removal
# Visualization wala method :

# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
 sns.boxplot(data=df, y="age", x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# IQR method 
Q1 = df["age"].quantile(0.25) 
Q3 = df["age"].quantile(0.75) 
IQR = Q3 - Q1 
IQR 
lower_bound = Q1 - 1.5 * IQR 
upper_bound = Q3 + 1.5 * IQR 
df = df[(df["age"] > lower_bound) & (df["age"] < upper_bound)]

# %%
df.shape
# Out:
# (703, 15)

# %%
es formula sy outlier koo remove kartey hai

# %%
sns.histplot(df["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df["fare"])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# the 3rd method is to remove out lier zscore method

# %%
import scipy as stats 
import numpy as np

# %%
zscore = np.abs(stats.z_score(df["age"])) 
threshold = 3 
df = df[(z < threshold).all(axis=1)]

# %% [markdown]
# Finding and dropping duplicates

# %%
how to find duplicates

# %%
df.shape
# Out:
# (703, 15)

# %%
df.duplicated().sum()
# Out:
# np.int64(36)

# %%
703-15
# Out:
# 688

# %%
df.drop_duplicates(inplace=True)

# %%
df_duplicates = df.duplicated() 
df_duplicates_count = df_duplicates.value_counts() 

plt.bar(df_duplicates_count.index, df_duplicates_count.values) 
plt.show()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (667, 15)

# %% [markdown]
# Data normalization

# %%
To bring data at one scale

# %%
1# pip install scikit-learn
# Out:
# 1

# %%
 
 import pandas as pd 
from sklearn.preprocessing import MinMaxScaler 

2# data 
df 

3.#select columns to normalize 
cols_to_normalize = ["age" , "fare"]  
#4. create the scaler function too 
scaler = MinMaxScaler() 

#5 fit and transform the data on scaler or vice versa 
df[cols_to_normalize] =scaler.fit_transform(df[cols_to_normalize]) 

#6 check the data 
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  0.339415      1      0  0.014151        S
# 1           1       1  female  0.591066      1      0  0.139136        C
# 2           1       3  female  0.402328      0      0  0.015469        S
# 3           1       1  female  0.543882      1      0  0.103644        S
# 4           0       3    male  0.543882      0      0  0.015713        S
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 883         0       2    male  0.433784      0      0  0.020495        S
# 885         0       3  female  0.606795      0      5  0.056848        Q
# 887         1       1  female  0.292230      0      0  0.058556        S
# 889         1       1    male  0.402328      0      0  0.058556        C
# 890         0       3    male  0.496697      0      0  0.015127        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  667.000000  667.000000  667.000000  667.000000  667.000000  667.000000
# mean     0.424288    2.227886    0.452835    0.541229    0.457271    0.070107
# std      0.494605    0.844841    0.219284    0.950435    0.874679    0.106115
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000    0.307958    0.000000    0.000000    0.015713
# 50%      0.000000    2.000000    0.433784    0.000000    0.000000    0.031425
# 75%      1.000000    3.000000    0.591066    1.000000    1.000000    0.068193
# max      1.000000    3.000000    1.000000    5.000000    6.000000    1.000000

# %%
x_stand = (x- mean(x)) /std(x) 

where: 

x_stand is the standardized variable x is the original variable mean (x) is the mean of the variable x std(x) 
is the standard deviation of variable x

# %% [markdown]
# Log Transformation

# %%
kashti = sns.load_dataset("titanic") 
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import numpy as np 
kashti["age"] = kashti["age"].fillna(kashti["age"].median()) 
kashti["fare"] = kashti["fare"].fillna(kashti["fare"].median()) 

# log transform 
kashti["age"] = np.log(kashti["age"]) 

kashti["fare"] = np.log(kashti["fare"]) 
kashti.head()
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    survived  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  3.091042      1      0  1.981001        S  Third
# 1         1       1  female  3.637586      1      0  4.266662        C  First
# 2         1       3  female  3.258097      0      0  2.070022        S  Third
# 3         1       1  female  3.555348      1      0  3.972177        S  First
# 4         0       3    male  3.555348      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# ...

# %%
sns.boxplot(data=kashti, x="sex", y="age")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=kashti, x="sex", y="fare")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.histplot(kashti["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# Oraganizing the data

# %%
df["family_size"] = df["sibsp"] + df["parch"]

# %%
sns.histplot(df["family_size"])
# Out:
# <Axes: xlabel='family_size', ylabel='Count'>

# %%
sns.swarmplot(data=df, x= "sex" , y="family_size")
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 56.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 27.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='family_size'>
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 72.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.swarmplot(data=df, x= "sex" , hue="family_size")
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex'>
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 87.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df = df.rename(columns={"survived": "survival"}) 
df.columns
# Out:
# Index(['survival', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'family_size'],
#       dtype='object')

# %%
table = pd.pivot_table(df, values="fare", index="pclass",
columns= "survival", aggfunc=np.sum)
table
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19912\281990521.py:1: FutureWarning: The provided callable <function sum at 0x000002D1E8D313A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table = pd.pivot_table(df, values="fare", index="pclass",
# survival         0          1
# pclass
# 1         7.938483  23.326311
# 2         3.313194   3.507771
# 3         6.602631   2.073065

# %%
sns.scatterplot(data=df , x="fare", y="age")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %% [markdown]
# SAVING THE WRANGLED DATA

# %%
df.to_csv("preprocesses_data.csv")
